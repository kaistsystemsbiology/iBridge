# %%
from cobra.io import read_sbml_model
from cobra.io import write_sbml_model
from cobra import Model, Reaction, Metabolite

import Simulator
import cobra
import copy
import pandas as pd
import numpy as np
import pandas as pd
import os
import glob
import time


def run_MetScore_simulation( filename, biomass_rxn, target_rxn, constdic={} ):
    simulator_obj = Simulator.Simulator()
    simulator_obj.read_model( filename )
    a,b,flux_dic = simulator_obj.run_FBA(internal_flux_minimization = True)
    wild_opt_flux = flux_dic
    print '#constraints', constdic
    #constdic[ biomass_rxn ] = [ 0.0 , 1000 ]
    
    new_objective_target = target_rxn        
    
    a,b,flux_dic = simulator_obj.run_FBA(new_objective = new_objective_target, flux_constraints = constdic, internal_flux_minimization = True, mode='max')
    max_const = flux_dic[ new_objective_target ]
     
    a,b,flux_dic = simulator_obj.run_FBA(new_objective = new_objective_target, flux_constraints = constdic, internal_flux_minimization = True, mode='min')    
    min_const = flux_dic[ new_objective_target ]    

    flux_dist_dic_set = {}   
    
    count = 1    
    for each_flux_const in np.linspace(min_const, max_const, 10):
        constdic2 = {}
        constdic2 = copy.deepcopy(constdic)
        count+=1
        constdic2[ new_objective_target ] = [ each_flux_const-each_flux_const*0.05, each_flux_const+each_flux_const*0.05]
        
        stat,obj_val,opt_flux_dic = simulator_obj.run_FBA(new_objective = biomass_rxn, flux_constraints = constdic2, mode='max')
        print opt_flux_dic[biomass_rxn]
        
        if stat != 2:
            continue
        
        constdic2[ biomass_rxn ] = [opt_flux_dic[biomass_rxn]-opt_flux_dic[biomass_rxn]*0.05, opt_flux_dic[biomass_rxn]+opt_flux_dic[biomass_rxn]*0.05]
        print constdic2
        
        stat,obj_val,flux_dic = simulator_obj.run_MOMA( wild_flux=wild_opt_flux, flux_constraints=constdic2)

        if stat == 2:
            flux_dist_dic_set[ each_flux_const ] = flux_dic
            
        if abs(flux_dic[biomass_rxn]) <= 10e-6:
            break

    flux_df = pd.DataFrame.from_dict(flux_dist_dic_set)
    flux_corr_df = flux_df.abs().T.corr()
    flux_cov_df = flux_df.abs().T.cov()
    return flux_df, flux_corr_df, flux_cov_df

def calculate_MetScore_sum(cobra_model, covariance_data):
    branch_metabolite_data = {}
    neighboring_rxns = {}

    for each_metabolite in cobra_model.metabolites:
        branch_metabolite_data[each_metabolite.id] = 0.0
        reactions = each_metabolite.reactions
        
        count = 0
        for each_reaction in reactions:
            reactants = [met.id for met in each_reaction.reactants]
            if each_metabolite.id in reactants:
                if each_reaction.id in covariance_data:
                    branch_metabolite_data[each_metabolite.id] += abs(covariance_data[each_reaction.id])
    
    return branch_metabolite_data

def select_candidates(cobra_model, target_reaction, output_file, metscore_df, corr_df, cov_df, corr_threshold=0, cov_threshold=0.1):
    pcorr_df = corr_df[corr_df > corr_threshold]
    pcov_df = cov_df[cov_df > cov_threshold]
    pcorr_df = pcorr_df.dropna()
    pcov_df = pcov_df.dropna()
    
    positive_candidate_reactions = list(set(pcorr_df.index)&set(pcov_df.index))
    
    ncorr_df = corr_df[corr_df < -corr_threshold]
    ncov_df = cov_df[cov_df < -cov_threshold]
    ncorr_df = ncorr_df.dropna()
    ncov_df = ncov_df.dropna()
    
    negative_candidate_reactions = list(set(ncorr_df.index)&set(ncov_df.index))
    
    print len(positive_candidate_reactions), len(negative_candidate_reactions)
    
    fp = open(output_file, 'w')
    print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%('Metabolite', 'Score', 'Normalized score', 'No. of reactions', 'No. of positive reactions', 'No. of negative reactions', 'candidate reactions', 'positive reactions', 'negative reactions', 'Positive score', 'Negative score')
    for each_row, each_df in metscore_df.iterrows():
        cobra_metabolite = cobra_model.metabolites.get_by_id(each_row)
        candidate_reactions = []

        for each_reaction in cobra_metabolite.reactions:
            for each_reactant in each_reaction.reactants:
                if each_reactant.id == each_row:
                    candidate_reactions.append(each_reaction.id)
        
        candidate_reactions = list(set(candidate_reactions))   
        pos_candidate_reactions = list(set(positive_candidate_reactions)&set(candidate_reactions))
        neg_candidate_reactions = list(set(negative_candidate_reactions)&set(candidate_reactions))
        
        positive_score = 0.0
        negative_score = 0.0
        for rxn in pos_candidate_reactions:
            positive_score+=float(pcov_df.loc[rxn])
        for rxn in neg_candidate_reactions:
            negative_score+=float(ncov_df.loc[rxn])
        if each_df[target_reaction] != 0.0 and np.sqrt(float(len(candidate_reactions))) != 0.0:
            normalized_score = each_df[target_reaction]/np.sqrt(float(len(candidate_reactions)))
        else:
            normalized_score = 0.0
        
        print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%(each_row, each_df[target_reaction], normalized_score, len(candidate_reactions), len(pos_candidate_reactions), len(neg_candidate_reactions), ';'.join(candidate_reactions), ';'.join(pos_candidate_reactions), ';'.join(neg_candidate_reactions),positive_score, negative_score)
    
    fp.close()
    return

def read_target_rxn(filename):
    fp = open(filename, 'r')
    lines = fp.read()
    lines = lines.replace('[', '')
    lines = lines.replace(']', '')
    lines = lines.replace("'", "")
    fp.close()
    target_rxn = lines.strip().split(',')
    print len(target_rxn)
    return target_rxn
    

def write_header(filename, taget_id):
    fp = open(filename, 'r')
    lines = fp.read()
    fp.close()
    fp = open(filename, 'w')
    print >>fp, '%s,%s'%('reaction', taget_id)
    print >>fp, lines.strip()
    fp.close()
    return

if __name__ == '__main__':
    #target_rxn_list = read_target_rxn('./target_product_reactions.txt')
    model_file = './input/ijo1366_IRR_indirubin.xml'
    original_model_file = './input/ijo1366_IRR.xml'
    biomass_rxn = 'Ec_biomass_iJO1366_core_53p95M'
    output_dir = './results/'
    target_rxn_list = ['EX_INDIRUBIN_LPAREN_e_RPAREN_']
    
    #Strain phenotype
    constrict={}
    constrict['PYK'] = [0.0, 0.0]
    
    
    cobra_model = read_sbml_model(model_file)
    original_cobra_model = read_sbml_model(original_model_file)

    for target_reaction in target_rxn_list:
        print target_reaction
        model_reactions = [reaction.id for reaction in cobra_model.reactions]

        corr_output = output_dir+'corr_%s.csv'%(target_reaction)
        cov_output = output_dir+'cov_%s.csv'%(target_reaction)

        flux_df, flux_corr_df, flux_cov_df = run_MetScore_simulation(model_file, biomass_rxn, target_reaction, constrict)
        flux_corr_df = flux_corr_df[target_reaction].ix[model_reactions]
        flux_corr_df.to_csv(corr_output)
        flux_cov_df = flux_cov_df[target_reaction].ix[model_reactions]
        flux_cov_df.to_csv(cov_output)

        write_header(corr_output, target_reaction)
        write_header(cov_output, target_reaction)

        df = pd.read_csv(cov_output, index_col=0, header=0)
        
        final_dic = {}
        for each_col in df.columns:
            final_dic[each_col]={}
            fluxsum_dic = calculate_MetScore_sum(cobra_model,  dict(df[each_col]))
            final_dic[each_col]=fluxsum_dic

        final_df = pd.DataFrame.from_dict(final_dic)
        final_df.to_csv(output_dir+'MetScore_%s.csv'%(target_reaction))

        flux_corr_df = pd.read_csv(corr_output, index_col=0)
        flux_cov_df = pd.read_csv(cov_output, index_col=0)
        output_file = output_dir+'Final_MetScore_%s.txt'%(target_reaction)
        select_candidates(cobra_model, target_reaction, output_file, final_df, flux_corr_df, flux_cov_df, 0, 0.0)
# Out:
# cobra/io/sbml.py:182 UserWarning: different charges specified for dcaACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2pglyc_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for eig3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2ahbut_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cinnm_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for feoxam_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pyr_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pyr_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pyr_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tdecoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for apg161_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for octa_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hmrsACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for octa_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5dglcn_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ps141_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arbt6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for uamag_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ump_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyc_DASH_R_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyc_DASH_R_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhgm_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for atp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ump_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2fe2s_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhgm_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gp4g_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for coa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for forcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyc_DASH_R_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for LalaDglu_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nmn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hbcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for crnDcoa_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipopb_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcur1p_e (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gtp_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gtp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for alac_DASH_S_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for s17bp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dmpp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cbl1_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for valtrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for no2_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cbl1_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cbl1_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for no2_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hkndd_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for no2_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2mecdp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4h2opntn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipa_e (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ascb6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cbp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for colipap_e (0 and -12)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arbtn_e (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arbtn_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for colipap_p (0 and -12)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arbtn_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5aizc_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hddecACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dhba_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcn_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for octa_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for aso3_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acglu_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ttdca_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cddec5eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ttdca_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ttdca_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acmum_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for kdo2lipid4p_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ac_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dhmb_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ac_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ac_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2obut_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2odecg3p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gthox_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ag_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tcynt_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ag_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tcynt_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipa_cold_e (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipa_cold_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for uacgam_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for colipa_p (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipa_cold_p (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for colipa_c (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for colipa_e (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for xmp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for xmp_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mg2_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for xmp_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mg2_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mg2_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3dhq_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for minohp_p (0 and -12)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nh4_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for bwco_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nh4_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nh4_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for minohp_e (0 and -12)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2dr5p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ttdcap_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein5p5p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tagdp_DASH_D_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gdp_e (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gslnt_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tre6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gdp_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for epmeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1tdecg3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5dglcn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3c3hmp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mocogdp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ddcacoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1tdecg3p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein5p4p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mmcoa_DASH_S_c (0 and -5)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4pasp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for LalaDgluMdapDala_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for LalaDgluMdapDala_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for LalaDgluMdapDala_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gam1p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for bwcogdp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gal1p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtbt_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3mob_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gal1p_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 25drapp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gal1p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5fthf_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1agpg160_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for xdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acmum6p_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for iasp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for didp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for aso3_e (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg161_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg161_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppa_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for spmd_c (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for spmd_e (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein3px3p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ump_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for spmd_p (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppa_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppa_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hexACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhgm_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acon_DASH_C_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dcmp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for flxr_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dcmp_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg120_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dcmp_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg120_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for stcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppi_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for oxam_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for malACP_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for uaagmda_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5apru_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for na15dap_c (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fprica_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mmet_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mmet_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mmet_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gar_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcur1p_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ggptrc_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2tpr3dpcoa_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1hdecg3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for clpn120_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for eca4colipa_e (0 and -15)
# cobra/io/sbml.py:182 UserWarning: different charges specified for malcoame_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for halipa_e (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gam6p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for eca4colipa_p (0 and -15)
# cobra/io/sbml.py:182 UserWarning: different charges specified for egmeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa140_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg180_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for adpglc_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acg5sa_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa140_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2me4p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for malt6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein4p4p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tartr_DASH_L_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tartr_DASH_L_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5prdmbz_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for skm_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for skm_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tartr_DASH_L_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for h_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppt_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3dcit_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 15dap_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for h_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for h_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 15dap_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppt_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 15dap_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3dcit_e (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for malcoa_c (0 and -5)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gthox_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gtp_e (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtdp4d6dm_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for adp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for moadcoo_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ugmd_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pmeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o16aund_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o16aund_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dhpppn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for zn2_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pheme_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tdeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for betald_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acon_DASH_T_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pheme_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3psme_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pheme_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fum_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fum_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5caiz_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for athtp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for r5p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23cgmp_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fum_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23cgmp_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for r5p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for r5p_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pgp160_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for xu5p_DASH_L_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tag6p_DASH_D_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pgp160_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3mop_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for xtp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cpg160_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for odecoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2odecg3p_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dappa_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppp9_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dappa_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2dh3dgal6p_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cph4_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dappa_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for urdglyc_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdca_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gthrd_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdca_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdca_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gthrd_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gthrd_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cpppg3_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for selnp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3ophb_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhm3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dhbzs_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for phpyr_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5mthf_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ptrc_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mnl1p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hpmeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for uama_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ptrc_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glu_DASH_L_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 13dpg_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2sephchc_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mso3_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg140_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3ps_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3ps_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mso3_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tsul_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg140_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3ps_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tsul_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tsul_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glu_DASH_L_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for msa_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcr_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcr_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtdp4d6dg_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cdpdodecg_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cit_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cit_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fdp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for isetac_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for isetac_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg181_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for aacoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for isetac_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipa_p (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg181_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1odec11eg3p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4ampm_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1odec11eg3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4adcho_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hpalmACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdcea_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pgp180_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galur_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdcea_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pphn_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for argtrna_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdcea_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galur_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galur_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lipa_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for psclys_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for psclys_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for psclys_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gdpofuc_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3pi_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3pi_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3pi_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for apg141_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galct_DASH_D_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galct_DASH_D_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galct_DASH_D_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcur_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcur_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hisp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acg5p_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sectrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcur_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for amet_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mlthf_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for u23ga_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for clpn181_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3c4mop_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gmhep1p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2shchc_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mal_DASH_D_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mpt_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cmp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for bmoco1gdp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dscl_c (0 and -7)
# cobra/io/sbml.py:182 UserWarning: different charges specified for clpn161_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mal_DASH_D_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for kdo_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pant_DASH_R_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for apg180_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fruur_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fruur_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fruur_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdceap_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for man1p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mal_DASH_L_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ps120_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mal_DASH_L_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mal_DASH_L_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ragund_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mettrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for phaccoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for camp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pdx5p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dhb_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdceap_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1hdec9eg3p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3ump_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1hdec9eg3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ptrc_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3ump_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdcea_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdcea_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ocdcea_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fmn_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for phom_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3_p (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pimACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for octdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for icolipa_c (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cynt_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3_c (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3_e (0 and 3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cynt_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cynt_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hpyr_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glcn_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hcddec5eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cl_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3ocvac11eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3oodcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23doguln_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cl_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sucglu_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hoctaACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdcap_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for frulysp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2mahmp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for imp_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for phphhlipa_c (0 and -10)
# cobra/io/sbml.py:182 UserWarning: different charges specified for f1p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dhna_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for imp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for feoxam_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for feoxam_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for u3hga_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cdg_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for t3c5ddeceACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hoctACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pram_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for apg160_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ru5p_DASH_L_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nmn_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for LalaDglu_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dutp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for LalaDglu_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udcpp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nmn_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anth_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for uacmamu_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hadpcoa_c (0 and -5)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tma_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pyam5p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for suchms_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for prpp_c (0 and -5)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tma_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tma_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3ig3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mobd_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3ooctdACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mobd_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa180_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for feoxam_DASH_un_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdca_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa180_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mobd_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ttdceap_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdca_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdca_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4per_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa161_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udpLa4n_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for aconm_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa161_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for nad_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sertrna_LSQBKT_sec_RSQBKT__c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dgslnt_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gam6p_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for b2coa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gam6p_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for chor_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for altrn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4abz_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for td2coa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3omrsACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ca2_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ogmeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1agpg141_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gmeACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for Sfglutth_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1tdec7eg3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1tdec7eg3p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for chol_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3odecACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udpLa4o_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for na1_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for na1_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for aact_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for chol_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cbasp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for chol_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for na1_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ugmda_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dnad_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtmp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtmp_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dd2coa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtmp_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dhacoa_c (0 and -5)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dadp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein3px4p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for agm_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for accoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3opalmACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for agm_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for agm_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hlipa_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for thmmp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa181_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for thptdn_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa181_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for octapb_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1agpg180_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ipdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for frulys_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tyrtrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for e4p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3oddecACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for preq1_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for frulys_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for asp_DASH_L_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for frulys_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ditp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3otdcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for micit_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sufbcd_DASH_2fe2s_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dhor_DASH_S_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hco3_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o2s_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3php_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o2s_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o2s_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sucorn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cdpdhdecg_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg140_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2tdecg3p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cdpdhdec9eg_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg140_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2tdecg3p_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acnam_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for butso3_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for butso3_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fadh2_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acnam_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acnam_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for butso3_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mptamp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cd2_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cd2_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg180_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cd2_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for paps_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cpg180_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg180_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2hdec9eg3p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein3p3p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hcinnm_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for adocbi_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2hdec9eg3p_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hcinnm_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gtspmd_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cechddd_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mso3_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for phetrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dudp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sufbcd_DASH_4fe4s_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dcacoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galctn_DASH_D_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gdpddman_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tcynt_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galctn_DASH_D_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2ippm_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galctn_DASH_D_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for thrtrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ps160_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for zn2_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pgp161_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cit_e (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for zn2_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for eca2und_p (0 and -4)
# ...
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hcmrs7eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dimp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dimp_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dgdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fecrm_DASH_un_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for adocbip_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ru5p_DASH_D_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for thm_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udcpdp_p (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for thm_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe2_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for moco_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe2_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for thm_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for unagamu_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe2_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyc3p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for uacmam_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg181_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arg_DASH_L_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg181_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arg_DASH_L_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for arg_DASH_L_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppbng_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glntrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ddca_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ddca_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sheme_c (0 and -8)
# cobra/io/sbml.py:182 UserWarning: different charges specified for amp_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ddca_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for histd_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for g3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for skm_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2ddglcn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2ddglcn_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2ddglcn_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lgt_DASH_S_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for moadamp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o16a4und_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for k_p (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fgam_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for all6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa160_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for quln_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa160_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cpgn_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cpgn_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for orot5p_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein4px4p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cpgn_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for but2eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for tdcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 23dhdp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2mcit_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ppcoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for kdolipid4_c (0 and -5)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 6pgl_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for rephaccoa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1agpg140_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for oxa_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2mcacn_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dhap_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 6pgc_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sucsal_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for murein5px4p_p (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4hbz_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cdec3eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2tdec7eg3p_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for crncoa_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2dhp_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dgtp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o16a4colipa_p (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ps181_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for o16a4colipa_e (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for cl_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1agpg181_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lac_DASH_L_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pydx5p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lac_DASH_L_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sl2a6o_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 4ppcys_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mococdp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lac_DASH_L_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 6hmhptpp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hemeO_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hdecACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for wco_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1odecg3p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for datp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1odecg3p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3sala_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa120_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dhcinnm_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3dhgulnp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pa120_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3dhguln_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hhexACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3hcvac11eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dtdpglu_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg141_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for op4en_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 2agpg141_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ddcaACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galctn_DASH_L_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galctn_DASH_L_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for clpn140_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for gthox_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for galctn_DASH_L_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lac_DASH_D_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for lac_DASH_D_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pydam_e (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for imp_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhm4p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3dhbzs_e (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3dhbzs_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for prbatp_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg160_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hx2coa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for fe3dhbzs_p (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ametam_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for pg160_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyclt_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyclt_e (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for glyclt_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for akg_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhgm4p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for akg_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hhlipa_c (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for akg_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for anhgm4p_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for toct2eACP_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3c2hmp_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for chtbs6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for enlipa_e (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for enlipa_p (0 and -6)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hacolipa_e (0 and -11)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sucbz_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for apg120_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for acgam6p_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 1agpg161_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for iletrna_c (0 and 1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for ghb_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3cmp_p (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 3cmp_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udcpdp_c (0 and -3)
# cobra/io/sbml.py:182 UserWarning: different charges specified for n8aspmd_c (0 and 2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dhpt_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for udpgalfur_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for sucgsa_c (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for 5dglcn_p (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for mana_c (0 and -1)
# cobra/io/sbml.py:182 UserWarning: different charges specified for dctp_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for hdd2coa_c (0 and -4)
# cobra/io/sbml.py:182 UserWarning: different charges specified for indirubin_e (0 and -2)
# cobra/io/sbml.py:182 UserWarning: different charges specified for indirubin_c (0 and -2)
# EX_INDIRUBIN_LPAREN_e_RPAREN_
# #constraints {'PYK': [0.0, 0.0]}
# 0.982371812726
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [0.0, 0.0], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.9332532220900549, 1.0314904033626922]}
# 0.880321706871
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [0.5622737686139749, 0.6214604810996565], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.8363056215274212, 0.9243377922145182]}
# 0.777386552028
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [1.1245475372279499, 1.242920962199313], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.7385172244264583, 0.8162558796292433]}
# 0.674451397185
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [1.6868213058419248, 1.8643814432989694], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.6407288273255901, 0.7081739670440733]}
# 0.571516242342
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [2.2490950744558997, 2.485841924398626], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.5429404302246883, 0.6000920544588659]}
# 0.46858183453
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [2.8113688430698747, 3.1073024054982823], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.4451527428033254, 0.49201092625630705]}
# 0.365646515583
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [3.3736426116838496, 3.7287628865979388], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.3473641898041239, 0.3839288413624528]}
# 0.262711196637
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [3.935916380297825, 4.350223367697596], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.2495756368051085, 0.27584675646880413]}
# 0.158952552285
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [4.4981901489117995, 4.971683848797252], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.15100492467032564, 0.16690017989878095]}
# 0.0510918918057
# {'EX_INDIRUBIN_LPAREN_e_RPAREN_': [5.060463917525774, 5.593144329896908], 'PYK': [0.0, 0.0], 'Ec_biomass_iJO1366_core_53p95M': [0.04853729721542896, 0.053646486396000434]}
# /data1/user_home/gbkim2/anaconda3/envs/engem/lib/python2.7/site-packages/ipykernel_launcher.py:174 DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /data1/user_home/gbkim2/anaconda3/envs/engem/lib/python2.7/site-packages/ipykernel_launcher.py:176 DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 171 464

# %%
cobra_model = cobra.io.load_json_model("./universal_model.json")
write_sbml_model(cobra_model, './bigg_universal_model.xml', use_fbc_package=False)


import pandas as pd
import os
import glob
from cobra.io import read_sbml_model
from cobra.io import write_sbml_model
import numpy as np

def make_candidate_reaction_sets(df, baasename):
    ex_metabolites = []
    with open('./excluded_metabolites.txt', 'r') as fp:
        for line in fp:
            ex_metabolites.append(line.strip())
            
    score_info = {}
    for each_met, each_df in df.groupby('Metabolite'):
            
        if each_met[-1] == 'c':
            pos_reaction_num = each_df['No. of positive reactions'].values[0]
            neg_reaction_num = each_df['No. of negative reactions'].values[0]

            pos_score = each_df['Positive score'].values[0]
            neg_scroe = each_df['Negative score'].values[0]
            
            final_pos_scroe = pos_score/np.sqrt(1+pos_reaction_num)
            final_neg_scroe = neg_scroe/np.sqrt(1+neg_reaction_num)
            score_info[each_met] = [final_pos_scroe, final_neg_scroe]

    negative_score_info = {}
    positive_score_info = {}
    
    for met in score_info:
        if abs(score_info[met][0]) > abs(score_info[met][1]):
            positive_score_info[met] = score_info[met][0]
        else:
            negative_score_info[met] = score_info[met][1]
      
    fp = open('./application_results/Candidate_%s'%(baasename), 'w')
    print >>fp, '%s\t%s\t%s\t%s'%('Negative metabolite', 'Positive metabolite', 'Negative score', 'Positive score')
    for negative_met in negative_score_info:
        negative_score = negative_score_info[negative_met]
        
        for positive_met in positive_score_info:
            
            if negative_met in ex_metabolites or positive_met in ex_metabolites:
                continue
            
            positive_score = positive_score_info[positive_met]
            print >>fp, '%s\t%s\t%s\t%s'%(negative_met, positive_met, negative_score, positive_score)
            
    fp.close()
    
files = glob.glob('./results/Final_*.txt')
print len(files)
for filename in files:
    baasename = os.path.basename(filename)
    df = pd.read_table(filename)
    make_candidate_reaction_sets(df, baasename)
# Out:
# 1

# %%
def check_reaction(filename, original_model_met_info, universal_model_met_info, flux_corr_df, flux_cov_df):
    
    
        
    basename = os.path.basename(filename)
    ex_reaction_id = basename.split('Final_MetScore_')[1].strip()
    ex_reaction_id = ex_reaction_id.replace('.txt', '')
    
    df = pd.read_table(filename)
    fp = open('./application_result2/New_reaction_candidate_%s'%(basename), 'w')
    print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%('Target', 'Gene source', 'Negative metabolite', 
                                                  'Positive metabolite', 'Negative score', 'Positive score', 
                                                  'Reaction', 'Equation', 'Corr', 'Cov')
    
    for each_row, each_df in df.iterrows():
        negative_met = each_df['Negative metabolite']
        positive_met = each_df['Positive metabolite']

        negative_score = each_df['Negative score']
        positive_score = each_df['Positive score']
        
        for each_met_set in original_model_met_info:
            if negative_met in each_met_set[0] and positive_met in each_met_set[1]:
                target_reaction = each_met_set[2]
                if target_reaction not in flux_corr_df.index:
                    print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%(ex_reaction_id, 'Native', negative_met, positive_met, 
                                                                      negative_score, positive_score, each_met_set[2], 
                                                                      each_met_set[3], 'NA', 'NA')
                else:
                    corr_val = float(flux_corr_df.ix[target_reaction])
                    cov_val = float(flux_cov_df.ix[target_reaction])
                    print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%(ex_reaction_id, 'Native', negative_met, positive_met, 
                                                                      negative_score, positive_score, each_met_set[2], 
                                                                      each_met_set[3], corr_val, cov_val)
                    
        
        for each_met_set in universal_model_met_info:
            if negative_met+'_' in each_met_set[0] and positive_met+'_' in each_met_set[1]:
                target_reaction = each_met_set[2]
                if target_reaction not in flux_corr_df.index:
                    print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%(ex_reaction_id, 'Universal model', negative_met, positive_met, 
                                                                      negative_score, positive_score, each_met_set[2], 
                                                                      each_met_set[3], 'NA', 'NA')
    fp.close()
    return

def metabolite_set(cobra_model):
    met_set_info = []
    for each_reaction in cobra_model.reactions:
        reactants = [str(met.id) for met in each_reaction.reactants]
        products = [str(met.id) for met in each_reaction.products]
        met_set_info.append([reactants, products, each_reaction.id, each_reaction.reaction])
        
    return met_set_info

def metabolite_set2(cobra_model):
    met_set_info = []
    for each_reaction in cobra_model.reactions:
        reactants = [str(met.id) for met in each_reaction.reactants]
        products = [str(met.id) for met in each_reaction.products]

        compartments = []
        for each_met in reactants+products:
            each_cmp = each_met[-2:]
            compartments.append(each_cmp)
            
        compartments = list(set(compartments))
        if len(compartments) == 1:
            if compartments[0] == 'c_':
                met_set_info.append([reactants, products, each_reaction.id, each_reaction.reaction])
        
    return met_set_info

original_model = './input/ijo1366_IRR.xml'
universal_model = './bigg_universal_model.xml'

original_cobra_model = read_sbml_model(original_model)
universal_cobra_model = read_sbml_model(universal_model)
#     print >>fp, '%s\t%s\t%s\t%s\t%s'%('Negative metabolite', 'Positive metabolite', 'Negative score', 'Positive score', 'Merged score')

original_model_met_set_info = metabolite_set(original_cobra_model)
universal_model_met_set_info = metabolite_set2(universal_cobra_model)
print len(original_model_met_set_info)
print len(universal_model_met_set_info)

files = glob.glob('./application_results/*.txt')
cov_dir = './results/'

cnt = 1
for each_file in files:
    s = time.time()
    basename = os.path.basename(each_file)
    print basename
    ex_reaction_id = basename.split('Final_MetScore_')[1].strip()
    ex_reaction_id = ex_reaction_id.replace('.txt', '')

    corr_file = glob.glob(cov_dir+'corr*%s*.csv'%(ex_reaction_id))[0]
    cov_file = glob.glob(cov_dir+'cov*%s*.csv'%(ex_reaction_id))[0]

    flux_corr_df = pd.read_csv(corr_file, index_col=0)
    flux_cov_df = pd.read_csv(cov_file, index_col=0)

    print ex_reaction_id, cnt

    check_reaction(each_file, original_model_met_set_info, universal_model_met_set_info, flux_corr_df, flux_cov_df)
    cnt+=1
    e = time.time()
    print e-s
# Out:
# 3193
# 11948
# Candidate_Final_MetScore_EX_INDIRUBIN_LPAREN_e_RPAREN_.txt
# EX_INDIRUBIN_LPAREN_e_RPAREN_ 1
# /data1/user_home/gbkim2/anaconda3/envs/engem/lib/python2.7/site-packages/ipykernel_launcher.py:30 DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /data1/user_home/gbkim2/anaconda3/envs/engem/lib/python2.7/site-packages/ipykernel_launcher.py:31 DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 131.529567003

# %%
def parse_reactions(reaction, ex_metabolites):
    reaction = reaction.replace('>', '')
    reaction = reaction.replace('<', '')
    
    sptlist = reaction.split('--')
    reactants = sptlist[0].strip().split(' + ')
    products = sptlist[0].strip().split(' + ')
    new_reactants = []
    new_products = []
    
    for met in reactants:
        if met not in ex_metabolites:
            new_reactants.append(met)
            
    for met in products:
        if met not in ex_metabolites:
            new_products.append(met)
            
    return new_reactants, new_products

def check_duplicate(reaction, known_reaction_info, ex_metabolites):
    flag = False
    reactants, products = parse_reactions(reaction, ex_metabolites)
    if len(reactants) > 0 and len(products) > 0: 
        for rxn in known_reaction_info:
            reactants2 = known_reaction_info[rxn][0]
            products2 = known_reaction_info[rxn][1]

            if  set(reactants).issubset(set(reactants2)) and set(products).issubset(set(products2)):
                flag = True
                return flag

            if  set(products).issubset(set(reactants2)) and set(reactants).issubset(set(products2)):
                flag = True
                return flag
        
    return flag

ex_metabolites = []
with open('./excluded_metabolites.txt', 'r') as fp:
    for line in fp:
        ex_metabolites.append(line.strip())

original_model = './input/ijo1366_IRR.xml'
original_cobra_model = read_sbml_model(original_model)

known_reaction_info = {}
for each_reaction in original_cobra_model.reactions:
    reactants, products = parse_reactions(each_reaction.reaction, ex_metabolites)
    known_reaction_info[each_reaction] = [reactants, products]
    
        
files = glob.glob('./application_result2/*.txt')
fp = open('./Application4_final_summary.txt', 'w')
print >>fp, '%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s\t%s'%('Target', 'Gene source', 'Negative metabolite', 
                                              'Positive metabolite', 'Negative score', 'Positive score', 
                                              'Reaction', 'Equation', 'Corr', 'Cov')
for each_file in files:
    with open(each_file, 'r') as fp2:
        fp2.readline()
        for line in fp2:
            sptlist = line.strip().split('\t')
            equation = sptlist[7].strip()
            met1 = sptlist[2].strip()
            met2 = sptlist[3].strip()
            if met1 not in ex_metabolites and met2 not in ex_metabolites:
                print >>fp, line.strip()

fp.close()
